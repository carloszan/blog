# %%
from fastapi import FastAPI, HTTPException
import httpx

create_container_input = {
    "HostConfig": {
        "Binds": [],
        "NetworkMode": "podman",
        "Dns": [],
        "ExtraHosts": [],
        "RestartPolicy": {
            "Name": "no"
        },
        "Privileged": False,
        "Init": False,
        "Runtime": "",
        "Devices": [],
        "Sysctls": {},
        "ShmSize": 67108864,
        "DeviceRequests": [],
        "NanoCpus": 0,
        "MemoryReservation": 0,
        "Memory": 0,
        "CapAdd": [
            "AUDIT_WRITE",
            "CHOWN",
            "DAC_OVERRIDE",
            "FOWNER",
            "FSETID",
            "KILL",
            "MKNOD",
            "NET_BIND_SERVICE",
            "NET_RAW",
            "SETFCAP",
            "SETGID",
            "SETPCAP",
            "SETUID",
            "SYS_CHROOT"
        ],
        "CapDrop": [
            "AUDIT_CONTROL",
            "BLOCK_SUSPEND",
            "DAC_READ_SEARCH",
            "IPC_LOCK",
            "IPC_OWNER",
            "LEASE",
            "LINUX_IMMUTABLE",
            "MAC_ADMIN",
            "MAC_OVERRIDE",
            "NET_ADMIN",
            "NET_BROADCAST",
            "SYSLOG",
            "SYS_ADMIN",
            "SYS_BOOT",
            "SYS_MODULE",
            "SYS_NICE",
            "SYS_PACCT",
            "SYS_PTRACE",
            "SYS_RAWIO",
            "SYS_RESOURCE",
            "SYS_TIME",
            "SYS_TTY_CONFIG",
            "WAKE_ALARM"
        ],
        "PublishAllPorts": False,
        "PortBindings": {
            "80/tcp": [
                {
                    "HostIp": "",
                    "HostPort": "8080"
                }
            ]
        },
        "AutoRemove": False
    },
    "NetworkingConfig": {
        "EndpointsConfig": {
            "podman": {
                "IPAMConfig": {
                    "IPv4Address": "",
                    "IPv6Address": ""
                }
            }
        }
    },
    "User": "",
    "WorkingDir": "",
    "OpenStdin": False,
    "Tty": False,
    "Volumes": {},
    "Hostname": "",
    "Domainname": "",
    "MacAddress": "",
    "Labels": {},
    "ExposedPorts": {
        "80/tcp": {}
    },
    "Env": [],
    "Image": "carloszan/blog:latest"
}

async def recreate_container_async():
  results = []
  headers = {'X-API-Key': 'ptr_iOezwi8bqTba/9jsKUFYYeAFLoO+fIyYYyk1bQD3qT8='}

  async with httpx.AsyncClient() as client:
      client.headers = headers
      # 1. Delete Container
      delete_response = await client.delete("https://portainer.home.sjdr.cloud/api/endpoints/4/docker/containers/blog?force=true")
      results.append({
          "request_number": 1,
          "method": "DELETE",
          "status_code": delete_response.status_code,
          "response": delete_response.text
      })

      # 2. Download Image
      download_image_response = await client.post("https://portainer.home.sjdr.cloud/api/endpoints/4/docker/images/create?fromImage=carloszan%2Fblog:latest", timeout=None)
      results.append({
          "request_number": 2,
          "method": "POST",
          "status_code": download_image_response.status_code,
          "response": download_image_response.text
      })

      # 3. Create Container
      create_container_response = await client.post("https://portainer.home.sjdr.cloud/api/endpoints/4/docker/containers/create?name=blog", json=create_container_input)
      results.append({
          "request_number": 3,
          "method": "POST",
          "status_code": create_container_response.status_code,
          "response": create_container_response.text
      })

      # 4. Start Container
      container_id = create_container_response.json()['Id']
      start_container_response = await client.post(f"https://portainer.home.sjdr.cloud/api/endpoints/4/docker/containers/{container_id}/start")
      results.append({
          "request_number": 4,
          "method": "POST",
          "status_code": start_container_response.status_code,
          "response": start_container_response.text
      })

      return results


results = await recreate_container_async()

# %%
results
# Out:
# [{'request_number': 1,
#   'method': 'DELETE',
#   'status_code': 404,
#   'response': '{"cause":"no such container","message":"no container with name or ID \\"blog\\" found: no such container","response":404}\n'},
#  {'request_number': 2,
#   'method': 'POST',
#   'status_code': 200,
#   'response': '{"status":"Already exists","progressDetail":{},"id":"078d56d567e7"}\n{"status":"Already exists","progressDetail":{},"id":"0368fd46e3c6"}\n{"status":"Already exists","progressDetail":{},"id":"6f9dcf64fee2"}\n{"status":"Already exists","progressDetail":{},"id":"d0b4991837de"}\n{"status":"Already exists","progressDetail":{},"id":"b50be7f3bf10"}\n{"status":"Already exists","progressDetail":{},"id":"049d729d0dee"}\n{"status":"Already exists","progressDetail":{},"id":"47b6f4b4b3a3"}\n{"status":"Already exists","progressDetail":{},"id":"786effc489a0"}\n{"status":"Pulling fs layer","progressDetail":{},"id":"40f11309248f"}\n{"status":"Pulling fs layer","progressDetail":{},"id":"82d3add76261"}\n{"status":"Download complete","progressDetail":{},"id":"40f11309248f"}\n{"status":"Pulling fs layer","progressDetail":{},"id":"9040b028720a"}\n{"status":"Download complete","progressDetail":{},"id":"82d3add76261"}\n{"status":"Download complete","progressDetail":{},"id":"9040b028720a"}\n{"status":"Pulling fs layer","progressDetail":{},"id":"bb9e498e7987"}\n{"status":"Download complete","progressDetail":{},"id":"bb9e498e7987"}\n{"status":"Download complete","progressDetail":{},"id":"bb9e498e7987"}\n'},
#  {'request_number': 3,
#   'method': 'POST',
#   'status_code': 200,
#   'response': '{"Id":"cacd631eaf1aad4de54950fc57b6c616a8db802af5bf42769abfe92ab3b1c19f","Portainer":{"ResourceControl":{"Id":18,"ResourceId":"cacd631eaf1aad4de54950fc57b6c616a8db802af5bf42769abfe92ab3b1c19f","SubResourceIds":[],"Type":1,"UserAccesses":[{"UserId":1,"AccessLevel":1}],"TeamAccesses":[],"Public":false,"AdministratorsOnly":false,"System":false}},"Warnings":[]}'},
#  {'request_number': 4, 'method': 'POST', 'status_code': 204, 'response': ''}]
